# %%
import numpy as np
import librosa

def spectral_subtraction(noisy_audio, sr, noise_sample, alpha=.1):

  n_fft = 2048
  hop_length = 512
  noisy_spectrogram = librosa.stft(noisy_audio, n_fft=n_fft, hop_length=hop_length)

  noisy_mag = np.abs(noisy_spectrogram)
  noisy_phase = np.angle(noisy_spectrogram)

  noise_spectrogram = librosa.stft(noise_sample, n_fft=n_fft, hop_length=hop_length)
  noise_mag, _ = np.abs(noise_spectrogram), np.angle(noise_spectrogram)
  noise_power_spectrum = np.mean(noise_mag**2, axis=1, keepdims=True)



  clean_mag = np.maximum(noisy_mag - alpha * noise_power_spectrum, 0)

  denoised_audio = librosa.istft(clean_mag * noisy_phase)

  return denoised_audio

noisy_audio, sr = librosa.load("/content/gm1_02_033.wav")
noise_sample, _ = librosa.load("/content/cabin-pressure_76bpm_F_minor.wav")


denoised_audio = spectral_subtraction(noisy_audio, sr, noise_sample)


from soundfile import write

write("denoised_audio.wav", denoised_audio, sr)

# %%
import numpy as np
import librosa
from soundfile import write

def spectral_subtraction(noisy_audio, sr, noise_sample, alpha=1):
    n_fft = 2048
    hop_length = 512
    noisy_spectrogram = librosa.stft(noisy_audio, n_fft=n_fft, hop_length=hop_length)

    noisy_mag = np.abs(noisy_spectrogram)
    noisy_phase = np.angle(noisy_spectrogram)

    if noise_sample.shape[0] < noisy_audio.shape[0]:
        noise_sample = np.pad(noise_sample, (0, noisy_audio.shape[0] - noise_sample.shape[0]), mode='constant')

    noise_spectrogram = librosa.stft(noise_sample, n_fft=n_fft, hop_length=hop_length)
    noise_mag, _ = np.abs(noise_spectrogram), np.angle(noise_spectrogram)

    if noise_mag.ndim > noisy_mag.ndim:
        noise_mag = noise_mag.squeeze()
    noise_power_spectrum = np.mean(noise_mag**2, axis=1, keepdims=True)

    clean_mag = np.maximum(noisy_mag - alpha * noise_power_spectrum, 0)

    denoised_audio = librosa.istft(clean_mag * noisy_phase)

    return denoised_audio

def evaluate_noise_reduction(noisy_audio, denoised_audio, sr):
    noisy_power = librosa.feature.rms(y=noisy_audio)[0]
    denoised_power = librosa.feature.rms(y=denoised_audio)[0]

    signal_power = np.mean(denoised_power**2)
    noise_power = np.mean(noisy_power**2) - signal_power

    epsilon = 1e-8
    noise_power = np.maximum(noise_power, epsilon)

    snr = 10 * np.log10(signal_power / noise_power)

    return snr


noisy_audio, sr_noisy = librosa.load("/content/gm1_02_033.wav")
denoised_audio, sr_denoised = librosa.load("/content/denoised_audio.wav")


evaluation_metrics = evaluate_noise_reduction(noisy_audio, denoised_audio, sr_noisy)
print("SNR:", evaluation_metrics)
# Out:
# SNR: 53.64247438063657

# %%
from transformers import AutoModelForCTC, Wav2Vec2Processor
import torch
import torchaudio
import string
def transcribe_with_wav2vec(file_path):
    model = AutoModelForCTC.from_pretrained("Jzuluaga/wav2vec2-large-960h-lv60-self-en-atc-uwb-atcc-and-atcosim")
    processor = Wav2Vec2Processor.from_pretrained("Jzuluaga/wav2vec2-large-960h-lv60-self-en-atc-uwb-atcc-and-atcosim")

    waveform, file_sampling_rate = torchaudio.load(file_path)
    if file_sampling_rate != 16000:
        waveform = torchaudio.transforms.Resample(orig_freq=file_sampling_rate, new_freq=16000)(waveform)

    waveform = waveform.squeeze(0)

    input_values = processor(waveform, return_tensors="pt", sampling_rate=16000).input_values

    with torch.no_grad():
        logits = model(input_values).logits

    pred_ids = torch.argmax(logits, dim=-1)
    transcription = processor.batch_decode(pred_ids)

    return transcription[0]
def customcorrection(predicttext,text):
    cleaned_ofrealtext = ''.join(char for char in text.lower() if char not in string.punctuation)
    cleaned_ofpredicttext = ''.join(char for char in predicttext.lower() if char not in string.punctuation)
    n_samples =len(cleaned_ofrealtext.split())
    n_correct=0

    for i in cleaned_ofpredicttext.split():
        if i in cleaned_ofrealtext.split():
            n_correct+=1
    return 1 * n_correct / n_samples
if __name__ == "__main__":
    audio_path = '/content/gm1_02_033.wav'

    transcription_wav2vec = transcribe_with_wav2vec(audio_path)
    print("Transcription (Wav2Vec 2.0):", transcription_wav2vec)
    print("ACC (Wav2Vec 2.0):", customcorrection(transcription_wav2vec,"sabena nine seven zero climb to flight level three four zero"))
    print("ACC (Wav2Vec 2.0):", customcorrection(transcription_wav2vec,"sabena nine seven zero climb to flight level three four zero"))
# Out:
# Some weights of the model checkpoint at Jzuluaga/wav2vec2-large-960h-lv60-self-en-atc-uwb-atcc-and-atcosim were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at Jzuluaga/wav2vec2-large-960h-lv60-self-en-atc-uwb-atcc-and-atcosim and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Transcription (Wav2Vec 2.0): sabena nine seven zero climb to flight level three four zero
# ACC (Wav2Vec 2.0): 1.0
# ACC (Wav2Vec 2.0): 1.0

# %%
from google.colab import drive
import os
from transformers import AutoModelForCTC, Wav2Vec2Processor
import torch
import torchaudio
import string

def transcribe_with_wav2vec(model, processor, file_path):
    waveform, file_sampling_rate = torchaudio.load(file_path)
    if file_sampling_rate != 16000:
        waveform = torchaudio.transforms.Resample(orig_freq=file_sampling_rate, new_freq=16000)(waveform)

    waveform = waveform.squeeze(0)

    input_values = processor(waveform, return_tensors="pt", sampling_rate=16000).input_values

    with torch.no_grad():
        logits = model(input_values).logits

    pred_ids = torch.argmax(logits, dim=-1)
    transcription = processor.batch_decode(pred_ids)

    return transcription[0]

def calculate_metrics(predicted_text, actual_text):
    predicted_text = ''.join(char for char in predicted_text.lower() if char not in string.punctuation)
    actual_text = ''.join(char for char in actual_text.lower() if char not in string.punctuation)

    predicted_words = predicted_text.split()
    actual_words = actual_text.split()

    true_positives = sum(1 for word in predicted_words if word in actual_words)
    false_positives = len(predicted_words) - true_positives
    false_negatives = len(actual_words) - true_positives

    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
    accuracy = true_positives / len(actual_words) if len(actual_words) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    wer = (false_positives + false_negatives) / len(actual_words) if len(actual_words) > 0 else 0
    ser = int(predicted_text != actual_text)

    return accuracy, precision, recall, f1_score, wer, ser


drive.mount('/content/drive')

if __name__ == "__main__":
    main_audio_dir = '/content/drive/MyDrive/wave_corrected'
    main_transcription_dir = '/content/drive/MyDrive/TXTdata'

    model = AutoModelForCTC.from_pretrained("Jzuluaga/wav2vec2-large-960h-lv60-self-en-atc-uwb-atcc-and-atcosim")
    processor = Wav2Vec2Processor.from_pretrained("Jzuluaga/wav2vec2-large-960h-lv60-self-en-atc-uwb-atcc-and-atcosim")

    total_accuracy = 0
    total_precision = 0
    total_recall = 0
    total_f1_score = 0
    total_wer = 0
    total_ser = 0
    num_files = 0

    for root, dirs, files in os.walk(main_audio_dir):
        for filename in files:
            if filename.endswith('.wav'):
                audio_path = os.path.join(root, filename)
                transcription_path = os.path.join(main_transcription_dir, os.path.relpath(audio_path, main_audio_dir)).replace('.wav', '.txt')

                if not os.path.exists(transcription_path):
                    print(f"Transcription file not found for {filename} at {transcription_path}. Skipping.")
                    continue

                with open(transcription_path, 'r') as f:
                    actual_transcription = f.read().strip()

                predicted_transcription = transcribe_with_wav2vec(model, processor, audio_path)
                accuracy, precision, recall, f1_score, wer, ser = calculate_metrics(predicted_transcription, actual_transcription)

                print(f"File: {filename}")
                print(f"Actual Transcription: {actual_transcription}")
                print(f"Predicted Transcription: {predicted_transcription}")
                print(f"Accuracy: {accuracy}")
                print(f"Precision: {precision}")
                print(f"Recall: {recall}")
                print(f"F1 Score: {f1_score}")
                print(f"WER: {wer}")
                print(f"SER: {ser}\n")

                total_accuracy += accuracy
                total_precision += precision
                total_recall += recall
                total_f1_score += f1_score
                total_wer += wer
                total_ser += ser
                num_files += 1

    if num_files > 0:
        overall_accuracy = total_accuracy / num_files
        overall_precision = total_precision / num_files
        overall_recall = total_recall / num_files
        overall_f1_score = total_f1_score / num_files
        overall_wer = total_wer / num_files
        overall_ser = total_ser / num_files
        print(f"Overall Accuracy: {overall_accuracy}")
        print(f"Overall Precision: {overall_precision}")
        print(f"Overall Recall: {overall_recall}")
        print(f"Overall F1 Score: {overall_f1_score}")
        print(f"Overall WER: {overall_wer}")
        print(f"Overall SER: {overall_ser}")
    else:
        print("No .wav files found in the specified directory.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Some weights of the model checkpoint at Jzuluaga/wav2vec2-large-960h-lv60-self-en-atc-uwb-atcc-and-atcosim were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at Jzuluaga/wav2vec2-large-960h-lv60-self-en-atc-uwb-atcc-and-atcosim and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Streaming output truncated to the last 5000 lines.
# File: sm4_03_090.wav
# Actual Transcription: tag alitalia two nine one identified
# Predicted Transcription: tag alitalia two nine one identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_096.wav
# Actual Transcription: tag nato ten identified
# Predicted Transcription: tag nato ten identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_097.wav
# Actual Transcription: and nato one zero proceed direct to norvenich november oscar romeo sierra
# Predicted Transcription: and nato one zero proceed direct to norvenich november oscar romeo sierra
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_105.wav
# Actual Transcription: tag gulf air five identified
# Predicted Transcription: tag gulf air five identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_100.wav
# Actual Transcription: tag malaysian four identified
# Predicted Transcription: tag malaysian four identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_098.wav
# Actual Transcription: cross air eight five eight contact rhein frequency one two seven three seven tschuss
# Predicted Transcription: crossair eight five eight contact rhein frequency one two seven three seven tschuss
# Accuracy: 0.8571428571428571
# Precision: 0.9230769230769231
# Recall: 0.8571428571428571
# F1 Score: 0.888888888888889
# WER: 0.21428571428571427
# SER: 1
#
# File: sm4_03_101.wav
# Actual Transcription: tag swissair nine three five nine identified
# Predicted Transcription: tag swiss air nine three five nine identified
# Accuracy: 0.8571428571428571
# Precision: 0.75
# Recall: 0.8571428571428571
# F1 Score: 0.7999999999999999
# WER: 0.42857142857142855
# SER: 1
#
# File: sm4_03_102.wav
# Actual Transcription: merair six nine five two proceed direct to trasadingen climb flight level three hundred
# Predicted Transcription: merair six nine five two proceed direct to trasadingen climb flight level three hundred
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_099.wav
# Actual Transcription: lufthansa three five five zero zurich one three four six tschuss
# Predicted Transcription: lufthansa three five five zero zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_104.wav
# Actual Transcription: tag lufthansa five two one seven identified
# Predicted Transcription: tag lufthansa five two one seven identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_103.wav
# Actual Transcription: affirm
# Predicted Transcription: affirm
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_111.wav
# Actual Transcription: @aerovic one zero six one report your heading
# Predicted Transcription: aerovic one zero six one report your heading
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_107.wav
# Actual Transcription: adria one six two seven contact rhein one three two four tschuss
# Predicted Transcription: adria one six two seven contact rhein one three two four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_114.wav
# Actual Transcription: tarom three seven four contact rhein frequency one three two four tschuss
# Predicted Transcription: tarom three seven four contact rhein frequency one three two four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_106.wav
# Actual Transcription: merair six nine four four guten tag identified i'll call you back shortly for higher
# Predicted Transcription: merair six nine four four guten tag identified i ll call you back shortly for higher
# Accuracy: 0.9333333333333333
# Precision: 0.875
# Recall: 0.9333333333333333
# F1 Score: 0.9032258064516129
# WER: 0.2
# SER: 1
#
# File: sm4_03_110.wav
# Actual Transcription: egyptair eight eight four guten tag identified
# Predicted Transcription: egypt air eight eight four guten tag identified
# Accuracy: 0.8571428571428571
# Precision: 0.75
# Recall: 0.8571428571428571
# F1 Score: 0.7999999999999999
# WER: 0.42857142857142855
# SER: 1
#
# File: sm4_03_109.wav
# Actual Transcription: and tarom three seven four proceed to tango
# Predicted Transcription: and tarom three seven four proceed to tango
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_108.wav
# Actual Transcription: tarom three seven four climb flight level three four zero
# Predicted Transcription: tarom three seven four climb flight level three four zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_113.wav
# Actual Transcription: delta india mike mike echo climb flight level two nine zero
# Predicted Transcription: delta india mike mike echo climb flight level two nine zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_112.wav
# Actual Transcription: roger continue heading one eight zero
# Predicted Transcription: roger continue heading one eight zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_121.wav
# Actual Transcription: meridiana six nine four four climb now flight level three zero zero
# Predicted Transcription: meridiana six nine four four climb now flight level three zero zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_120.wav
# Actual Transcription: tag delta charlie india november alfa identified climb flight level two seven zero
# Predicted Transcription: tag delta charlie india november alfa identified climb flight level two seven zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_119.wav
# Actual Transcription: roger please reduce to point seven two until advised
# Predicted Transcription: roger please reduce to point seven two until advised
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_116.wav
# Actual Transcription: lufthansa five five zero four zurich one three four six tschuss
# Predicted Transcription: lufthansa five five zero four zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_118.wav
# Actual Transcription: merair one zero s= correction @aerovic one zero six one what is your mach number
# Predicted Transcription: merair one zero correction aerovic one zero six one what is your mach number
# Accuracy: 0.9333333333333333
# Precision: 1.0
# Recall: 0.9333333333333333
# F1 Score: 0.9655172413793104
# WER: 0.06666666666666667
# SER: 1
#
# File: sm4_03_122.wav
# Actual Transcription: alitalia two nine one report your mach number
# Predicted Transcription: alitalia two nine one report your mach number
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_115.wav
# Actual Transcription: alitalia two nine one turn right heading one eight zero
# Predicted Transcription: alitalia two nine one turn right heading one eight zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_117.wav
# Actual Transcription: alitalia one five zero contact rhein one two seven three seven tschuss
# Predicted Transcription: alitalia one five zero contact rhein one two seven three seven tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_133.wav
# Actual Transcription: gulf air five rhein one two seven three seven tschuss
# Predicted Transcription: gulf air five rhein one two seven three seven tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_125.wav
# Actual Transcription: meridiana six nine five two contact zurich one three four six tschuss
# Predicted Transcription: meridiana six nine five two contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_127.wav
# Actual Transcription: malay=
# Predicted Transcription: malays
# Accuracy: 0.0
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0
# WER: 2.0
# SER: 1
#
# File: sm4_03_124.wav
# Actual Transcription: roger please do so until advised
# Predicted Transcription: roger please do so until advised
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_132.wav
# Actual Transcription: tag sunwing five two one four identified transmission break malaysian four contact rhein one two seven three seven
# Predicted Transcription: tag sunwing five two one four identified transmission break malaysian four contact rhein one two seven three seven
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_126.wav
# Actual Transcription: tunis air four eight zero two guten tag identified
# Predicted Transcription: tunis air four eight zero two guten tag identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_123.wav
# Actual Transcription: roger are you able to increase to point seven eight or more
# Predicted Transcription: roger are you able to increase to point seven eight or more
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_131.wav
# Actual Transcription: malaysian four contact rhein one two seven three seven
# Predicted Transcription: malaysian four contact rhein one two seven three seven
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_129.wav
# Actual Transcription: [EMPTY]
# Predicted Transcription:
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# WER: 1.0
# SER: 1
#
# File: sm4_03_130.wav
# Actual Transcription: tag sunwing five two one two identified
# Predicted Transcription: tag sunwing five two one two identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_128.wav
# Actual Transcription: tag alitalia one three five identified
# Predicted Transcription: tag alitalia one three five identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_139.wav
# Actual Transcription: lufthansa five two one seven proceed direct to dinkelsbuhl
# Predicted Transcription: lufthansa five two one seven proceed direct to dinkelsbuhl
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_142.wav
# Actual Transcription: nato z= one zero contact rhein one two seven three seven tschuss
# Predicted Transcription: nato one zero contact rhein one two seven three seven tschuss
# Accuracy: 0.9166666666666666
# Precision: 1.0
# Recall: 0.9166666666666666
# F1 Score: 0.9565217391304348
# WER: 0.08333333333333333
# SER: 1
#
# File: sm4_03_140.wav
# Actual Transcription: @aerovic one zero six one contact zurich frequency one three four six tschuss
# Predicted Transcription: aerovic one zero six one contact zurich frequency one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_141.wav
# Actual Transcription: alitalia two nine one likewise zurich one three four six tschuss
# Predicted Transcription: alitalia two nine one likewise zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_137.wav
# Actual Transcription: sunwing five two one two report your heading
# Predicted Transcription: sunwing five two one two report your heading
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_134.wav
# Actual Transcription: negative gulf air zero zero five
# Predicted Transcription: negative gulf air zero zero five
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_138.wav
# Actual Transcription: roger turn right heading one nine zero
# Predicted Transcription: roger turn right heading one nine zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_135.wav
# Actual Transcription: delta india mike mike echo zurich one three four six tschuss
# Predicted Transcription: delta india mike mike echo zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_136.wav
# Actual Transcription: tag alitalia three six nine identified
# Predicted Transcription: tag alitalia three six nine identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_147.wav
# Actual Transcription: swissair five correction swissair nine three five nine continue descent now flight level two nine zero two thousand feet per minute or more
# Predicted Transcription: swiss air five correction swiss air nine three five nine continue descent now flight level two nine zero two thousand feet per minute or more
# Accuracy: 0.9130434782608695
# Precision: 0.84
# Recall: 0.9130434782608695
# F1 Score: 0.8749999999999999
# WER: 0.2608695652173913
# SER: 1
#
# File: sm4_03_144.wav
# Actual Transcription: britannia three zero six alfa contact rhein frequency one three two decimal four tschuss
# Predicted Transcription: britannia three zero six alfa contact rhein frequency one three two decimal four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_143.wav
# Actual Transcription: swissair nine three five nine descend now flight level three four zero
# Predicted Transcription: swiss air nine three five nine descend now flight level three four zero
# Accuracy: 0.9166666666666666
# Precision: 0.8461538461538461
# Recall: 0.9166666666666666
# F1 Score: 0.8799999999999999
# WER: 0.25
# SER: 1
#
# File: sm4_03_146.wav
# Actual Transcription: delta charlie india november alfa climb to flight level two nine zero
# Predicted Transcription: delta charlie india november alfa climb to flight level two nine zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_148.wav
# Actual Transcription: tag algerie two zero seven three identified continue current heading climb flight level two seven zero
# Predicted Transcription: tag algerie two zero seven three identified continue current heading climb flight level two seven zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_145.wav
# Actual Transcription: lufthansa five two one seven contact rhein one three two four tschuss
# Predicted Transcription: lufthansa five two one seven contact rhein one three two four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_150.wav
# Actual Transcription: tag delta india bravo echo charlie identified
# Predicted Transcription: tag delta india bravo echo charlie identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_155.wav
# Actual Transcription: roger turn right heading one three five
# Predicted Transcription: roger turn right heading one three five
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_151.wav
# Actual Transcription: swissair nine three five nine contact rhein one three two decimal four tschuss
# Predicted Transcription: swiss air nine three five nine contact rhein one three two decimal four tschuss
# Accuracy: 0.9230769230769231
# Precision: 0.8571428571428571
# Recall: 0.9230769230769231
# F1 Score: 0.888888888888889
# WER: 0.23076923076923078
# SER: 1
#
# File: sm4_03_157.wav
# Actual Transcription: algerie two zero seven three climb flight level three hundred
# Predicted Transcription: algerie two zero seven three climb flight level three hundred
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_154.wav
# Actual Transcription: alitalia four six nine report your heading correction alitalia three six nine report your heading
# Predicted Transcription: alitalia four six nine report your heading correction alitalia three six nine report your heading
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_149.wav
# Actual Transcription: negative the current heading you're maintaining and climb to flight level two seven zero
# Predicted Transcription: negative the current heading you are maintaining and climb to flight level two seven zero
# Accuracy: 0.9285714285714286
# Precision: 0.8666666666666667
# Recall: 0.9285714285714286
# F1 Score: 0.896551724137931
# WER: 0.21428571428571427
# SER: 1
#
# File: sm4_03_152.wav
# Actual Transcription: [EMPTY]
# Predicted Transcription:
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# WER: 1.0
# SER: 1
#
# File: sm4_03_156.wav
# Actual Transcription: sunwing five two one four correction five two one two direct to trasadingen
# Predicted Transcription: sunwing five two one four correction five two one two direct to trasadingen
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_153.wav
# Actual Transcription: egyptair eight eight four contact rhein one three two decimal four tschuss
# Predicted Transcription: egypt air eight eight four contact rhein one three two decimal four tschuss
# Accuracy: 0.9166666666666666
# Precision: 0.8461538461538461
# Recall: 0.9166666666666666
# F1 Score: 0.8799999999999999
# WER: 0.25
# SER: 1
#
# File: sm4_03_160.wav
# Actual Transcription: tag lufthansa four two one nine identified
# Predicted Transcription: tag lufthansa four two one nine identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_161.wav
# Actual Transcription: tag scandinavian six eight seven identified
# Predicted Transcription: tag scandinavian six eight seven identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_158.wav
# Actual Transcription: tag aero lloyd five six two climb flight level two seven zero
# Predicted Transcription: tag aero lloyd five six two climb flight level two seven zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_162.wav
# Actual Transcription: alitalia three six nine direct to trasadingen
# Predicted Transcription: alitalia three six nine direct to trasadingen
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_159.wav
# Actual Transcription: algerie two zero seven three proceed direct no for the time being continue on heading one seven zero
# Predicted Transcription: algerie two zero seven three proceed direct no for the time being continue on heading one seven zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_165.wav
# Actual Transcription: meridiana six nine four four zurich one three four six tschuss
# Predicted Transcription: meridiana six nine four four zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_167.wav
# Actual Transcription: tag alitalia four six nine identified
# Predicted Transcription: tag alitalia four six nine identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_166.wav
# Actual Transcription: tag lufthansa three five zero eight identified climb flight level two five zero
# Predicted Transcription: tag lufthansa three five zero eight identified climb flight level two five zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_164.wav
# Actual Transcription: merair six nine four four contact zurich one three four six tschuss
# Predicted Transcription: merair six nine four four contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_168.wav
# Actual Transcription: tag lufthansa three three three zero identified
# Predicted Transcription: tag lufthansa three three three zero identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_163.wav
# Actual Transcription: algerie two zero seven three direct to trasadingen now
# Predicted Transcription: algerie two zero seven three direct to trasadingen now
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_170.wav
# Actual Transcription: tag lufthansa four five eight two identified
# Predicted Transcription: tag lufthansa four five eight two identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_171.wav
# Actual Transcription: [EMPTY]
# Predicted Transcription:
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# WER: 1.0
# SER: 1
#
# File: sm4_03_172.wav
# Actual Transcription: [EMPTY]
# Predicted Transcription:
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# WER: 1.0
# SER: 1
#
# File: sm4_03_169.wav
# Actual Transcription: alitalia three six nine descend flight level two nine zero
# Predicted Transcription: alitalia three six nine descend flight level two nine zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_173.wav
# Actual Transcription: alitalia three six nine rate of descent two thousand feet per minute or more
# Predicted Transcription: alitalia three six nine rate of descent two thousand feet per minute or more
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_177.wav
# Actual Transcription: five six two
# Predicted Transcription: five six two
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_174.wav
# Actual Transcription: sunwing five two one two contact zurich one three four six tschuss
# Predicted Transcription: sunwing five two one two contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_176.wav
# Actual Transcription: aero lloyd five six two proceed correct no aero lloyd five six two direct to hochwald hotel oscar charlie thereafter st prex sierra papa romeo
# Predicted Transcription: aero lloyd five six two proceed correct no aero lloyd five six two direct to hochwald hotel oscar charlie thereafter st prex sierra papa romeo
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_175.wav
# Actual Transcription: alitalia one three five zurich one three four six tschuss
# Predicted Transcription: alitalia one three five zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_183.wav
# Actual Transcription: tunis air four eight zero two contact rhein one two seven three seven tschuss
# Predicted Transcription: tunis air four eight zero two contact rhein one two seven three seven tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_182.wav
# Actual Transcription: lufthansa three five zero eight climb flight level three zero zero expedite climb
# Predicted Transcription: lufthansa three five zero eight climb flight level three zero zero expedite climb
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_181.wav
# Actual Transcription: and aero lloyd five six two climb flight level two nine zero
# Predicted Transcription: and aero lloyd five six two climb flight level two nine zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_184.wav
# Actual Transcription: delta echo charlie direct to d= dinkelsbuhl
# Predicted Transcription: delta echo charlie direct to  dinkelsbuhl
# Accuracy: 0.8571428571428571
# Precision: 1.0
# Recall: 0.8571428571428571
# F1 Score: 0.923076923076923
# WER: 0.14285714285714285
# SER: 1
#
# File: sm4_03_179.wav
# Actual Transcription: [EMPTY]
# Predicted Transcription:
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# WER: 1.0
# SER: 1
#
# File: sm4_03_185.wav
# Actual Transcription: delta echo charlie descend now flight level three five zero
# Predicted Transcription: delta echo charlie descend now flight level three five zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_178.wav
# Actual Transcription: aero lloyd five six two to hochwald thereafter st prex
# Predicted Transcription: aero lloyd five six two to hochwald thereafter st prex
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_180.wav
# Actual Transcription: that is right aero lloyd five six two but turn right now to the point hotel oscar charlie that's a point in the computer i suggest a right turn ohh it looks very good for the present position
# Predicted Transcription: that is right aero lloyd five six two but turn right now to the point hotel oscar charlie that s a point in the computer i suggest e right turn o it looks very good for the present position
# Accuracy: 0.9473684210526315
# Precision: 0.9230769230769231
# Recall: 0.9473684210526315
# F1 Score: 0.935064935064935
# WER: 0.13157894736842105
# SER: 1
#
# File: sm4_03_189.wav
# Actual Transcription: sunwing five two one four contact zurich one three three four tschuss
# Predicted Transcription: sunwing five two one four contact zurich one three three four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_190.wav
# Actual Transcription: lufthansa four two one nine proceed direct to dinkelsbuhl
# Predicted Transcription: lufthansa four two one nine proceed direct to dinkelsbuhl
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_186.wav
# Actual Transcription: lufthansa four five eight two climb to flight level two seven zero
# Predicted Transcription: lufthansa four five eight two climb to flight level two seven zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_187.wav
# Actual Transcription: lufthansa three three three zero climb flight level two seven zero
# Predicted Transcription: lufthansa three three three zero climb flight level two seven zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_191.wav
# Actual Transcription: delta charlie india november alfa contact zurich one three four six tschuss
# Predicted Transcription: delta charlie india november alfa contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_188.wav
# Actual Transcription: air algerie two zero seven three contact zurich one three four six tschuss
# Predicted Transcription: air algerie two zero seven three contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_198.wav
# Actual Transcription: lufthansa four two one nine contact rhein one three two four tschuss
# Predicted Transcription: lufthansa four two one nine contact rhein one three two four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_192.wav
# Actual Transcription: alitalia three six nine zurich one three four six tschuss
# Predicted Transcription: alitalia three six nine zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_199.wav
# Actual Transcription: aero lloyd five six two zurich one three four six tschuss
# Predicted Transcription: aero lloyd five six two zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_196.wav
# Actual Transcription: delta echo charlie descend flight level three four zero now
# Predicted Transcription: delta echo charlie descend flight level three four zero now
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_195.wav
# Actual Transcription: please do so
# Predicted Transcription: please do so
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_200.wav
# Actual Transcription: lufthansa three five zero eight speed at own convenience contact zurich one three four six tschuss
# Predicted Transcription: lufthansa three five zero eight speed at own convenience contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_193.wav
# Actual Transcription: lufthansa three five zero eight report your mach number
# Predicted Transcription: lufthansa three five zero eight report your mach number
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_194.wav
# Actual Transcription: roger are you able to cruise with [NONSENSE] point seven five
# Predicted Transcription: roger are you able to cruise with p point seven five
# Accuracy: 0.9090909090909091
# Precision: 0.9090909090909091
# Recall: 0.9090909090909091
# F1 Score: 0.9090909090909091
# WER: 0.18181818181818182
# SER: 1
#
# File: sm4_03_197.wav
# Actual Transcription: delta india bravo echo charlie contact rhein one three two decimal four
# Predicted Transcription: delta india bravo echo charlie contact rhein one three two decimal four
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_202.wav
# Actual Transcription: tag sabena eight zero six identified
# Predicted Transcription: tag sabena eight zero six identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_03_203.wav
# Actual Transcription: <OT> danke </OT>
# Predicted Transcription: danke
# Accuracy: 0.3333333333333333
# Precision: 1.0
# Recall: 0.3333333333333333
# F1 Score: 0.5
# WER: 0.6666666666666666
# SER: 1
#
# File: sm4_03_201.wav
# Actual Transcription: lufthansa four five eight two climb flight level three hundred
# Predicted Transcription: lufthansa four five eight two climb flight level three hundred
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_007.wav
# Actual Transcription: sobelair two five two one contact rhein one three two decimal four tschuss
# Predicted Transcription: sobelair two five two one contact rhein one three two decimal four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_002.wav
# Actual Transcription: lufthansa four four zero eight climb flight level two nine zero now
# Predicted Transcription: lufthansa four four zero eight climb flight level two nine zero now
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_005.wav
# Actual Transcription: berlin five two five five direct to frankfurt
# Predicted Transcription: berlin five two five five direct to frankfurt
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_001.wav
# Actual Transcription: delta india hotel echo bravo climb flight level two nine zero now
# Predicted Transcription: delta india hotel echo bravo climb flight level two nine zero now
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_003.wav
# Actual Transcription: delta echo bravo zurich one three four decimal six tschuss
# Predicted Transcription: delta echo bravo zurich one three four decimal six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_004.wav
# Actual Transcription: ah air berlin five two five five guten tag identified
# Predicted Transcription: air berlin five two five five guten tag identified
# Accuracy: 0.9
# Precision: 1.0
# Recall: 0.9
# F1 Score: 0.9473684210526316
# WER: 0.1
# SER: 1
#
# File: sm4_02_006.wav
# Actual Transcription: tag tarom three seven two identified
# Predicted Transcription: tag tarom three seven two identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_010.wav
# Actual Transcription: tag swissair nine three six zero identified
# Predicted Transcription: tag swiss air nine three six zero identified
# Accuracy: 0.8571428571428571
# Precision: 0.75
# Recall: 0.8571428571428571
# F1 Score: 0.7999999999999999
# WER: 0.42857142857142855
# SER: 1
#
# File: sm4_02_017.wav
# Actual Transcription: airals one zero eight eight contact rhein one two seven three seven tschuss
# Predicted Transcription: airals one zero eight eight contact rhein one two seven three seven tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_015.wav
# Actual Transcription: tag lufthansa three six zero four identified climb flight level two seven zero
# Predicted Transcription: tag lufthansa three six zero four identified climb flight level two seven zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_013.wav
# Actual Transcription: tag hapag lloyd one one two identified direct frankfurt
# Predicted Transcription: tag hapag lloyd one one two identified direct frankfurt
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_016.wav
# Actual Transcription: [EMPTY]
# Predicted Transcription:
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# WER: 1.0
# SER: 1
#
# File: sm4_02_014.wav
# Actual Transcription: tag sabena eight three zero identified
# Predicted Transcription: tag sabena eight three zero identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_012.wav
# Actual Transcription: swissair eight zero six contact rhein one two seven three seven tschuss
# Predicted Transcription: swiss air eight zero six contact rhein one two seven three seven tschuss
# Accuracy: 0.9166666666666666
# Precision: 0.8461538461538461
# Recall: 0.9166666666666666
# F1 Score: 0.8799999999999999
# WER: 0.25
# SER: 1
#
# File: sm4_02_011.wav
# Actual Transcription: tag lufthansa three five six six identified climb flight level two seven zero
# Predicted Transcription: tag lufthansa three five six six identified climb flight level two seven zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_009.wav
# Actual Transcription: lufthansa four four zero eight contact zurich frequency one three four six tschuss
# Predicted Transcription: lufthansa four four zero eight contact zurich frequency one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_008.wav
# Actual Transcription: tag swiss eight zero six identified climb to flight level three one zero
# Predicted Transcription: tag swiss eight zero six identified climb to flight level three one zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_021.wav
# Actual Transcription: tag
# Predicted Transcription: tag
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_024.wav
# Actual Transcription: swissair nine three six zero climb flight level three one zero now
# Predicted Transcription: swiss air nine three six zero climb flight level three one zero now
# Accuracy: 0.9166666666666666
# Precision: 0.8461538461538461
# Recall: 0.9166666666666666
# F1 Score: 0.8799999999999999
# WER: 0.25
# SER: 1
#
# File: sm4_02_025.wav
# Actual Transcription: and nine three six zero contact rhein one two seven three seven tschu
# Predicted Transcription: and nines three six zero contact rhein one two seven three seven tschu
# Accuracy: 0.9230769230769231
# Precision: 0.9230769230769231
# Recall: 0.9230769230769231
# F1 Score: 0.9230769230769231
# WER: 0.15384615384615385
# SER: 1
#
# File: sm4_02_018.wav
# Actual Transcription: lufthansa three five six six direct trasadingen climb flight level two nine zero
# Predicted Transcription: lufthansa three five six six direct trasadingen climb flight level two nine zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_019.wav
# Actual Transcription: berlin five two five five rhein one two seven three seven tschu
# Predicted Transcription: berlin five two five five rhein one two seven three seven tschu
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_020.wav
# Actual Transcription: lufthansa three six zero four climb flight level two nine zero fly direct to trasadingen
# Predicted Transcription: lufthansa three six zero four climb flight level two nine zero fly direct to trasadingen
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_022.wav
# Actual Transcription: ah alitalia six four seven four guten tag identified maintain the current heading for the time being
# Predicted Transcription: alitalia six four seven four guten tag identified maintain the current heading for the time being
# Accuracy: 0.9411764705882353
# Precision: 1.0
# Recall: 0.9411764705882353
# F1 Score: 0.9696969696969697
# WER: 0.058823529411764705
# SER: 1
#
# File: sm4_02_023.wav
# Actual Transcription: tarom three seven two contact rhein frequency one three two decimal four tschuss
# Predicted Transcription: tarom three seven two contact rhein frequency one three two decimal four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_031.wav
# Actual Transcription: [EMPTY]
# Predicted Transcription:
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# WER: 1.0
# SER: 1
#
# File: sm4_02_029.wav
# Actual Transcription: so proceed via charlie oscar romeo november alfa to nattenheim thereafter that corna to direct to november tango mike
# Predicted Transcription: so proceed via charlie oscar romeo november alfa to nattenheim thereafter that corna to direct to november tango mike
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_032.wav
# Actual Transcription: [EMPTY]
# Predicted Transcription:
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# WER: 1.0
# SER: 1
#
# File: sm4_02_028.wav
# Actual Transcription: affirm can you fly to that point
# Predicted Transcription: affirm can you fly to that point
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_026.wav
# Actual Transcription: hoi ~k ~l ~m three four six identified are you familiar with the point corna charlie oscar romeo november alfa
# Predicted Transcription: hoi klm three four six identified are you familiar with the point corna charlie oscar romeo november alfa
# Accuracy: 0.85
# Precision: 0.9444444444444444
# Recall: 0.85
# F1 Score: 0.8947368421052632
# WER: 0.2
# SER: 1
#
# File: sm4_02_033.wav
# Actual Transcription: roger no problems or report the current heading
# Predicted Transcription: roger no problem sorr report the current heading
# Accuracy: 0.75
# Precision: 0.75
# Recall: 0.75
# F1 Score: 0.75
# WER: 0.5
# SER: 1
#
# File: sm4_02_034.wav
# Actual Transcription: roger to for radar vectors to nattenheim turn left heading three four five
# Predicted Transcription: roger to for radar vectors to nattenheim turn left heading three four five
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_027.wav
# Actual Transcription: oh sorry ~k ~l ~m three four six are you familiar with the point corna charlie oscar romeo november alfa
# Predicted Transcription: o sorry klm three four six are you familiar with the point corna charlie oscar romeo november alfa
# Accuracy: 0.8
# Precision: 0.8888888888888888
# Recall: 0.8
# F1 Score: 0.8421052631578948
# WER: 0.3
# SER: 1
#
# File: sm4_02_030.wav
# Actual Transcription: alita=
# Predicted Transcription: alita
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_035.wav
# Actual Transcription: alitalia six four seven four direct to fox fox mike
# Predicted Transcription: alitalia six four seven four direct to fox fox mike
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_039.wav
# Actual Transcription: ah lufthansa five two three six guten tag identified
# Predicted Transcription: lufthansa five two three six guten tag identified
# Accuracy: 0.8888888888888888
# Precision: 1.0
# Recall: 0.8888888888888888
# F1 Score: 0.9411764705882353
# WER: 0.1111111111111111
# SER: 1
#
# File: sm4_02_038.wav
# Actual Transcription: lufthansa four seven zero zero guten tag identified climb to flight level two nine zero
# Predicted Transcription: lufthansa four seven zero zero guten tag identified climb to flight level two nine zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_036.wav
# Actual Transcription: sabena eight three zero contact rhein one two seven three seven tschu
# Predicted Transcription: sabena eight three zero contact rhein one two seven three seven tschu
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_041.wav
# Actual Transcription: ah speedbird one two nine guten tag identified
# Predicted Transcription: speed bird one two nine guten tag identified
# Accuracy: 0.75
# Precision: 0.75
# Recall: 0.75
# F1 Score: 0.75
# WER: 0.5
# SER: 1
#
# File: sm4_02_042.wav
# Actual Transcription: lufthansa three five si= six six contact zurich one three four six tschuss
# Predicted Transcription: lufthansa three five si six six contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_040.wav
# Actual Transcription: ~k ~l ~m three four six to stay clear later on french military air space turn right heading three five zero
# Predicted Transcription: klm three four six to stay clear later on french military air space turn right heading three five zero
# Accuracy: 0.8571428571428571
# Precision: 0.9473684210526315
# Recall: 0.8571428571428571
# F1 Score: 0.9
# WER: 0.19047619047619047
# SER: 1
#
# File: sm4_02_037.wav
# Actual Transcription: guten tag britannia three two seven alfa identified
# Predicted Transcription: guten tag britannia three two seven alfa identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_043.wav
# Actual Transcription: tag lufthansa four two zero seven identified proceed direct to dinkelsbuhl delta kilo bravo
# Predicted Transcription: tag lufthansa four two zero seven identified proceed direct to dinkelsbuhl delta kilo bravo
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_048.wav
# Actual Transcription: hapag lloyd one one two contact rhein one two seven three seven tschuss
# Predicted Transcription: hapag lloyd one one two contact rhein one two seven three seven tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_044.wav
# Actual Transcription: [EMPTY]
# Predicted Transcription:
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# WER: 1.0
# SER: 1
#
# File: sm4_02_049.wav
# Actual Transcription: [HNOISE] tag golf bravo victor juliett india identified
# Predicted Transcription: tag golf bravo victor juliett india identified
# Accuracy: 0.875
# Precision: 1.0
# Recall: 0.875
# F1 Score: 0.9333333333333333
# WER: 0.125
# SER: 1
#
# File: sm4_02_045.wav
# Actual Transcription: britannia three two seven alfa proceed direct to kempten
# Predicted Transcription: britannia three two seven alfa proceed direct to kempten
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_050.wav
# Actual Transcription: golf juliett india report your heading
# Predicted Transcription: golf juliett india report your heading
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_052.wav
# Actual Transcription: roger and now turn right heading one three eight
# Predicted Transcription: roger and now turn right heading one three eight
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_047.wav
# Actual Transcription: lufthansa three six zero four contact zurich one three four decimal six tschuss
# Predicted Transcription: lufthansa three six zero four contact zurich one three four decimal six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_051.wav
# Actual Transcription: roger continue heading one three eight radar vectors to trasadingen
# Predicted Transcription: roger continue heading one three eight radar vectors to trasadingen
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_046.wav
# Actual Transcription: and three two seven alfa contact rhein one three two decimal four tschuss
# Predicted Transcription: and three two seven alfa contact rhein one three two decimal four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_055.wav
# Actual Transcription: okay hotel tango romeo climb flight level three five zero two thousand feet per minute or more
# Predicted Transcription: ok hotel tango romeo climb flight level three five zero two thousand feet per minute or more
# Accuracy: 0.9411764705882353
# Precision: 0.9411764705882353
# Recall: 0.9411764705882353
# F1 Score: 0.9411764705882353
# WER: 0.11764705882352941
# SER: 1
#
# File: sm4_02_053.wav
# Actual Transcription: tag hotel bravo india tango romeo identified i'll call you back shortly for higher
# Predicted Transcription: tag hotel bravo india tango romeo identified i ll call you back shortly for higher
# Accuracy: 0.9285714285714286
# Precision: 0.8666666666666667
# Recall: 0.9285714285714286
# F1 Score: 0.896551724137931
# WER: 0.21428571428571427
# SER: 1
#
# File: sm4_02_059.wav
# Actual Transcription: speedbird one two nine contact rhein one three two four tschuss
# Predicted Transcription: speed bird one two nine contact rhein one three two four tschuss
# Accuracy: 0.9090909090909091
# Precision: 0.8333333333333334
# Recall: 0.9090909090909091
# F1 Score: 0.8695652173913043
# WER: 0.2727272727272727
# SER: 1
#
# File: sm4_02_058.wav
# Actual Transcription: tag saudia one zero six identified
# Predicted Transcription: tag saudia one zero six identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_056.wav
# Actual Transcription: lufthansa five two three six contact rhein one two seven three seven tschu
# Predicted Transcription: lufthansa five two three six contact rhein one two seven three seven tschu
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_061.wav
# Actual Transcription: ~k ~l ~m three four six proceed now direct to nattenheim november tango mike
# Predicted Transcription: klm three four six proceed now direct to nattenheim november tango mike
# Accuracy: 0.7857142857142857
# Precision: 0.9166666666666666
# Recall: 0.7857142857142857
# F1 Score: 0.8461538461538461
# WER: 0.2857142857142857
# SER: 1
#
# File: sm4_02_057.wav
# Actual Transcription: lufthansa four two zero seven contact rhein one three two decimal four tschuss
# Predicted Transcription: lufthansa four two zero seven contact rhein one three two decimal four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_054.wav
# Actual Transcription: hotel tango romeo are you able to climb with two thousand feet per minute or more
# Predicted Transcription: hotel tango romeo are you able to climb with two thousand feet per minute or more
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_060.wav
# Actual Transcription: lufthansa four seven zero zero zurich one three four six tschuss
# Predicted Transcription: lufthansa four seven zero zero zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_069.wav
# Actual Transcription: hotel bravo india tango romeo contact rhein one two seven three seven tschuss
# Predicted Transcription: hotel bravo india tango romeo contact rhein one two seven three seven tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_02_068.wav
# Actual Transcription: bee med one guten tag identified
# Predicted Transcription: bee med one guten tag identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# ...
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_129.wav
# Actual Transcription: merair six nine five two contact zurich one three four six
# Predicted Transcription: merair six nine five two contact zurich one three four six
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_125.wav
# Actual Transcription: [EMPTY]
# Predicted Transcription:
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# WER: 1.0
# SER: 1
#
# File: sm4_01_134.wav
# Actual Transcription: [EMPTY]
# Predicted Transcription:
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# WER: 1.0
# SER: 1
#
# File: sm4_01_133.wav
# Actual Transcription: [HNOISE] merair six nine four four climb now flight level three one zero one thousand five hundred or more
# Predicted Transcription: merair six nine four four climb now flight level three one zero one thousand five hundred or more
# Accuracy: 0.9473684210526315
# Precision: 1.0
# Recall: 0.9473684210526315
# F1 Score: 0.972972972972973
# WER: 0.05263157894736842
# SER: 1
#
# File: sm4_01_140.wav
# Actual Transcription: @aerovic one zero six one milano one three four five two tschuss
# Predicted Transcription: aerovic one zero six one milano one three four five two tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_138.wav
# Actual Transcription: tarom three seven four rhein one three two decimal four
# Predicted Transcription: tarom three seven four rhein one three two decimal four
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_143.wav
# Actual Transcription: swissair nine three five nine contact rhein one three two four tschuss
# Predicted Transcription: swiss air nine three five nine contact rhein one three two four tschuss
# Accuracy: 0.9166666666666666
# Precision: 0.8461538461538461
# Recall: 0.9166666666666666
# F1 Score: 0.8799999999999999
# WER: 0.25
# SER: 1
#
# File: sm4_01_137.wav
# Actual Transcription: tarom three seven four
# Predicted Transcription: tarom three seven four
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_136.wav
# Actual Transcription: tarom three seven four rhein one three two four tschuss
# Predicted Transcription: tarom three seven four rhein one three two four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_139.wav
# Actual Transcription: swissair nine three five nine descend now flight level three one zero
# Predicted Transcription: swiss air nine three five nine descend now flight level three one zero
# Accuracy: 0.9166666666666666
# Precision: 0.8461538461538461
# Recall: 0.9166666666666666
# F1 Score: 0.8799999999999999
# WER: 0.25
# SER: 1
#
# File: sm4_01_141.wav
# Actual Transcription: gulf air five contact rhein one two seven three seven tschuss
# Predicted Transcription: gulf air five contact rhein one two seven three seven tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_144.wav
# Actual Transcription: lufthansa five two one seven descend now flight level three one zero
# Predicted Transcription: lufthansa five two one seven descend now flight level three one zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_135.wav
# Actual Transcription: tag alitalia three six nine identified
# Predicted Transcription: tag alitalia three six nine identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_142.wav
# Actual Transcription: britan= britannia three zero six alfa rhein one two seven three seven tschuss
# Predicted Transcription: britan britannia three zero six alfa rhein one two seven three seven tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_151.wav
# Actual Transcription: [EMPTY]
# Predicted Transcription:
# Accuracy: 0.0
# Precision: 0
# Recall: 0.0
# F1 Score: 0
# WER: 1.0
# SER: 1
#
# File: sm4_01_153.wav
# Actual Transcription: algerie two zero seven three climb now flight level two nine zero
# Predicted Transcription: algerie two zero seven three climb now flight level two nine zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_147.wav
# Actual Transcription: delta india bravo echo charlie guten tag identified
# Predicted Transcription: delta india bravo echo charlie guten tag identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_155.wav
# Actual Transcription: tag scandinavian six eight seven identified
# Predicted Transcription: tag scandinavian six eight seven identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_154.wav
# Actual Transcription: [HNOISE] aero lloyd five six two climb flight level two nine zero continue current heading
# Predicted Transcription: aero lloyd five six two climb flight level two nine zero continue current heading
# Accuracy: 0.9333333333333333
# Precision: 1.0
# Recall: 0.9333333333333333
# F1 Score: 0.9655172413793104
# WER: 0.06666666666666667
# SER: 1
#
# File: sm4_01_152.wav
# Actual Transcription: britannia three zero six alfa
# Predicted Transcription: britannia three zero six alfa
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_148.wav
# Actual Transcription: steel eight eight contact rhein one three two decimal four tschuss
# Predicted Transcription: steel eight eight contact rhein one three two decimal four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_146.wav
# Actual Transcription: tag algerie two zero seven three identified climb flight level two five zero continue current heading
# Predicted Transcription: tag algerie two zero seven three identified climb flight level two five zero continue current heading
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_145.wav
# Actual Transcription: five two one seven rhein one three two four tschuss
# Predicted Transcription: five two one seven rhein one three two four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_149.wav
# Actual Transcription: meridiana six nine four four contact zurich one three four six tschuss
# Predicted Transcription: meridiana six nine four four contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_150.wav
# Actual Transcription: tag aero lloyd five six two identified climb flight level two seven zero
# Predicted Transcription: tag aero lloyd five six two identified climb flight level two seven zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_164.wav
# Actual Transcription: aero lloyd five six two direct to trasadingen
# Predicted Transcription: aero lloyd five six two direct to trasadingen
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_162.wav
# Actual Transcription: tag lufthansa four two one nine identified
# Predicted Transcription: tag lufthansa four two one nine identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_161.wav
# Actual Transcription: air algerie two zero seven three direct to trasadingen
# Predicted Transcription: air algerie two zero seven three direct to trasadingen
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_159.wav
# Actual Transcription: roger break alitalia three six nine what is your mach number
# Predicted Transcription: roger break alitalia three six nine what is your mach number
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_163.wav
# Actual Transcription: tag lufthansa three five zero eight identified climb flight level two five zero
# Predicted Transcription: tag lufthansa three five zero eight identified climb flight level two five zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_160.wav
# Actual Transcription: roger three six nine direct to trasadingen expect descent in about one minute
# Predicted Transcription: roger three six nine direct to trasadingen expect descent in about one minute
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_158.wav
# Actual Transcription: alitalia one three five what is you mach number
# Predicted Transcription: alitalia one three five what is your mach number
# Accuracy: 0.8888888888888888
# Precision: 0.8888888888888888
# Recall: 0.8888888888888888
# F1 Score: 0.8888888888888888
# WER: 0.2222222222222222
# SER: 1
#
# File: sm4_01_157.wav
# Actual Transcription: alitalia four six nine guten tag identified
# Predicted Transcription: alitalia four six nine guten tag identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_156.wav
# Actual Transcription: sunwing five two one four descend now flight level three seven zero
# Predicted Transcription: sunwing five two one four descend now flight level three seven zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_167.wav
# Actual Transcription: alitalia three six nine descend now flight level three one zero one thousand five hundred feet f= per minute or more
# Predicted Transcription: alitalia three six nine descend now flight level three one zero one thousand five hundred feet per minute or more
# Accuracy: 0.9523809523809523
# Precision: 1.0
# Recall: 0.9523809523809523
# F1 Score: 0.975609756097561
# WER: 0.047619047619047616
# SER: 1
#
# File: sm4_01_166.wav
# Actual Transcription: tag lufthansa three three three zero identified climb flight level two five zero continue heading
# Predicted Transcription: tag lufthansa three three three zero identified climb flight level two five zero continue heading
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_172.wav
# Actual Transcription: tunis air four eight zero two contact rhein one two seven three seven tschu
# Predicted Transcription: tunis air four eight zero two contact rhein one two seven three seven tschu
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_168.wav
# Actual Transcription: aero lloyd five six two expect further climb in about two minutes one coming clear of opposite traffic one thousand feet higher later on
# Predicted Transcription: aero lloyd five six two expect further climb in about two minutes one coming clear of opposite traffic one thousand feet higher later on
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_170.wav
# Actual Transcription: alitalia one three five contact zurich one three four six tschuss
# Predicted Transcription: alitalia one three five contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_171.wav
# Actual Transcription: tag lufthansa four five eight two identified
# Predicted Transcription: tag lufthansa four five eight two identified
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_169.wav
# Actual Transcription: lufthansa three five zero eight climb flight level two eight zero now
# Predicted Transcription: lufthansa three five zero eight climb flight level two eight zero now
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_165.wav
# Actual Transcription: delta echo charlie direct to dinkelsbuhl
# Predicted Transcription: delta echo charlie direct to dinkelsbuhl
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_179.wav
# Actual Transcription: algerie two zero seven three contact zurich one three four six tschuss
# Predicted Transcription: algerie two zero seven three contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_180.wav
# Actual Transcription: delta charlie india november alfa contact rhein one two seven three seven tschuss
# Predicted Transcription: delta charlie india november alfa contact rhein one two seven three seven tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_177.wav
# Actual Transcription: lufthansa three five zero eight continue climb flight level two nine zero
# Predicted Transcription: lufthansa three five zero eight continue climb flight level two nine zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_178.wav
# Actual Transcription: delta india bravo echo charlie descend now flight level three seven zero
# Predicted Transcription: delta india bravo echo charlie descend now flight level three seven zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_174.wav
# Actual Transcription: sunwing five two one two correction sunwing five two one four zurich one three three four tschuss
# Predicted Transcription: sunwing five two one two correction sunwing five two one four zurich one three three four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_173.wav
# Actual Transcription: sunwing five two one two contact zurich one three four six tschuss
# Predicted Transcription: sunwing five two one two contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_181.wav
# Actual Transcription: alitalia three six nine zurich one three four six tschuss
# Predicted Transcription: alitalia three six nine zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_176.wav
# Actual Transcription: lufthansa three three three zero climb flight level two nine zero
# Predicted Transcription: lufthansa three three three zero climb flight level two nine zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_175.wav
# Actual Transcription: aero lloyd five six two climb flight level three one zero now
# Predicted Transcription: aero lloyd five six two climb flight level three one zero now
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_182.wav
# Actual Transcription: lufthansa four five eight two climb flight level two nine zero
# Predicted Transcription: lufthansa four five eight two climb flight level two nine zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_185.wav
# Actual Transcription: delta echo charlie rhein one three two four tschuss
# Predicted Transcription: delta echo charlie rhein one three two four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_184.wav
# Actual Transcription: delta echo charlie continue descent now flight level three five zero
# Predicted Transcription: delta echo charlie continue descent now flight level three five zero
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_187.wav
# Actual Transcription: lufthansa four two one nine contact rhein one three two four tschuss
# Predicted Transcription: lufthansa four two one nine contact rhein one three two four tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_190.wav
# Actual Transcription: scandinavian six eight seven likewise zurich one three four six tschuss
# Predicted Transcription: scandinavian six eight seven likewise zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_188.wav
# Actual Transcription: lufthansa three five zero eight contact zurich one three four six tschuss
# Predicted Transcription: lufthansa three five zero eight contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0
#
# File: sm4_01_186.wav
# Actual Transcription: aero lloyd five six two contact zurich one three four six tschuss
# Predicted Transcription: aero lloyd five six two contact zurich one three four six tschuss
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# WER: 0.0
# SER: 0

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import librosa
from scipy.signal import spectrogram
from scipy.linalg import norm

def compute_metrics(audio1_path, audio2_path):
    y1, sr1 = librosa.load(audio1_path, sr=16000)
    y2, sr2 = librosa.load(audio2_path, sr=16000)

    if sr1 != sr2:
        raise ValueError("Sample rates do not match.")

    f1, t1, Sxx1 = spectrogram(y1, sr1)
    f2, t2, Sxx2 = spectrogram(y2, sr2)

    min_len = min(Sxx1.shape[1], Sxx2.shape[1])
    Sxx1 = Sxx1[:, :min_len]
    Sxx2 = Sxx2[:, :min_len]

    mse = np.mean((Sxx1 - Sxx2) ** 2)

    signal_power = np.sum(Sxx1 ** 2)
    noise_power = np.sum((Sxx1 - Sxx2) ** 2)
    snr = 10 * np.log10(signal_power / noise_power)

    sc = norm(Sxx1 - Sxx2) / norm(Sxx1)

    return {
        'MSE': mse,
        'SNR': snr,
        'Spectral Convergence': sc
    }

metrics = compute_metrics( '/content/denoised_audio.wav','/content/gm1_02_033.wav')
print(metrics)
# Out:
# {'MSE': 3.1334737e-12, 'SNR': 5.813494920730591, 'Spectral Convergence': 0.5120652}

# %%
import numpy as np
import librosa

noisy_audio, sr_noisy = librosa.load("/content/gm1_02_033.wav", sr=16000)
denoised_audio, sr_denoised = librosa.load("/content/denoised_audio.wav", sr=16000)

if sr_noisy != sr_denoised:
    raise ValueError("Sample rates of the noisy and denoised audio files do not match")


min_length = min(len(noisy_audio), len(denoised_audio))
noisy_audio = noisy_audio[:min_length]
denoised_audio = denoised_audio[:min_length]


noise = noisy_audio - denoised_audio


signal_power = np.mean(denoised_audio ** 2)
noise_power = np.mean(noise ** 2)


snr = 10 * np.log10(signal_power / noise_power)

print(f"SNR: {snr:.2f} dB")
# Out:
# SNR: -2.56 dB
